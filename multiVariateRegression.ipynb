# %% [markdown]
# <a href="https://colab.research.google.com/github/sheCodesAI/ML_mini_models/blob/main/multiVariateRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df = pd.read_csv("/content/house_prices_multi.csv")

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %% [markdown]
# above data looks like linear

# %% [markdown]
# # **Topics**
# - ### Data Processing: Handling NA values
# - ### Linear Resgression using Multiple Variables
# : Instead of 1 input → you use multiple inputs
# Example:
# Area 🏠
# Bedrooms 🛏️
# Age ⏳
#
# 👉 All together predict Price 💰
# ---

# %% [markdown]
# 👉 b = just numbers (coefficients)
#
# 👉 They are not in your data table ❌
#
# 👉 They are created by ML ✅

# %% [markdown]
# ## **y=b0​+b1​x1​+b2​x2​+b3​x3​**

# %% [markdown]
# 🔵 Dots = your real data points
#
# 📈 Line = ML’s prediction line
# (this is created using b values)
#
# ML finds best b → best line → best prediction

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %% [markdown]
# # handle missing value by taking median

# %%
df.bedrooms.median()
# Out:
# 3.5

# %%
df.fillna(3.5, inplace = True)

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       3.5   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %% [markdown]
# before apply any ml models,
# do preprocess and clean

# %%
model = linear_model.LinearRegression()
model.fit(df[['area', 'bedrooms', 'age']], df.price)
# Out:
# LinearRegression()

# %%
model.coef_
# means check wt values ML predicted to b
# Out:
# array([    198.47159002, -116583.73881651,  -14267.77585936])

# %%
model.intercept_
# Out:
# np.float64(656046.539004866)

# %%
model.predict([[4000,4,30]])
# here we predicted price, by passing area, bedrooms, old_age
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([555564.668027])

# %% [markdown]
# ### **how it calculated the prev price?**

# %%
model.coef_
# Out:
# array([    198.47159002, -116583.73881651,  -14267.77585936])

# %%
198.47*4000 + -116583*4 + -14267*30 + 656046.539
# Out:
# 555584.539

# %% [markdown]
# we used formula here
#
# y=b0​+b1​x1​+b2​x2​+b3​x3​
#
# where b are the values predicted by ML, check val : model_coef_
