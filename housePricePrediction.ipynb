# %% [markdown]
# <a href="https://colab.research.google.com/github/sheCodesAI/ML_mini_models/blob/main/housePricePrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("/content/house_prices.csv")

# %%
df

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area, df.price, color= 'red', marker = "+")
plt.plot(df.area, model, model.predict(df[['area']]), color='blue')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1338/475676778.py in <cell line: 0>()
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 plt.xlabel('area')
#       3 plt.ylabel('price')
#       4 plt.scatter(df.area, df.price, color= 'red', marker = "+")
#       5 plt.plot(df.area, model, model.predict(df[['area']]), color='blue')
#
# NameError: name 'plt' is not defined

# %%
model = linear_model.LinearRegression()
model.fit(df[['area']], df.price) # x, y axis

# %%
# now this model is ready to predict the prices

# %%
model.predict(pd.DataFrame([3300]))

# %%
model.coef_

# %%
model.intercept_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1338/1895106156.py in <cell line: 0>()
# ----> 1 model.intercept_
#
# NameError: name 'model' is not defined
